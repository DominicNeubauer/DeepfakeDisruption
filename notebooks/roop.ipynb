# %% [markdown]
# Roop Repository: https://github.com/s0md3v/roop.git

# %% [markdown]
# # **Step 1: Initialization**

# %%
# !git clone https://github.com/s0md3v/roop.git
# %cd roop

# !pip install -r requirements.txt

# %%
# !wget https://civitai.com/api/download/models/85159 -O inswapper_128.onnx

# %%
# !pip uninstall onnxruntime onnxruntime-gpu -y
#!pip install torch torchvision torchaudio --force-reinstall --index-url https://download.pytorch.org/whl/cu118
# !pip install onnxruntime-gpu

# %% [markdown]
# # **Step 2: Run the deepfake code**

# %%
#--target -> the target video path
#--source -> the source image path
#--o -> result video path

# !python /content/roop/run.py --target "/content/drive/MyDrive/Colab Notebooks/assets/New Test Video.mp4"  --source "/content/drive/MyDrive/Colab Notebooks/assets/Face Pictures/FaceImage.jpg" -o "/content/drive/MyDrive/Colab Notebooks/output.mp4" --execution-provider cuda --frame-processor face_swapper face_enhancer
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_runtime.py:184: UserWarning: Pydantic is installed but cannot be imported. Please check your installation. `huggingface_hub` will default to not using Pydantic. Error message: '{e}'
#   warnings.warn(
# Downloading: 529MB [00:02, 222MB/s]
# Downloading: 332MB [00:02, 128MB/s]
# download_path: /root/.insightface/models/buffalo_l
# ...
# 100% 281857/281857 [00:05<00:00, 50745.40KB/s]
# 2024-04-21 14:33:06.358551800 [E:onnxruntime:Default, provider_bridge_ort.cc:1548 TryGetProviderInfo_CUDA] /onnxruntime_src/onnxruntime/core/session/provider_bridge_ort.cc:1209 onnxruntime::Provider& onnxruntime::ProviderLibrary::Get() [ONNXRuntimeError] : 1 : FAIL : Failed to load library libonnxruntime_providers_cuda.so with error: libcufft.so.10: cannot open shared object file: No such file or directory
#
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# ...
